# %% [markdown]
# <a href="https://colab.research.google.com/github/Taqdees07/AI-WITH-SVTTI/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#Sample dataset with missing values and duplicates
df=pd.DataFrame( {
    'Name':['Alice','Bob','Claire', 'Alice'],
    'Age':[25,np.nan,35,25],
    'Salary':[50000,60000,np.nan,50000]
})

#Remove duplicate rows
df=df.drop_duplicates()

# Fill missing values
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Salary'].fillna(df['Salary'].median(),inplace=True)

print(df)
